# %%
import pandas as pd

df = pd.read_csv("../dados/brutos/pesquisa_salarial_2024.csv")

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), str(100)
# memory usage: 56.9 MB

# %%
df[["Country", "YearsCodePro", "DevType", "ConvertedCompYearly", "RemoteWork"]].head(10)
# Out:
#                                              Country YearsCodePro  \
# 0                           United States of America          NaN
# 1  United Kingdom of Great Britain and Northern I...           17
# 2  United Kingdom of Great Britain and Northern I...           27
# 3                                             Canada          NaN
# 4                                             Norway          NaN
# 5                           United States of America          NaN
# 6                           United States of America            7
# 7                                         Uzbekistan          NaN
# 8  United Kingdom of Great Britain and Northern I...          NaN
# 9                                             Serbia           11
#
#                  DevType  ConvertedCompYearly RemoteWork
# 0                    NaN                  NaN     Remote
# 1  Developer, full-stack                  NaN     Remote
# 2   Developer Experience                  NaN     Remote
# ...

# %%
df["ConvertedCompYearly"].notna().sum()
# Out:
# np.int64(23435)
